# %%
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Feb 26 11:39:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.8/921.8 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # Correct
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 106MB/s]

# %%
train_result = model.train(
    data="/content/drive/MyDrive/potholesecond/Copy of data.yaml",
    epochs=100,
    imgsz=640,
    device=0,
)
# Out:
# Ultralytics 8.3.79 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images", save=True)
results[0].show()
# Out:
# image 1/59 /content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images/1014745_RS_386_386RS124739_30651_RAW_jpg.rf.c096a4242067d93b7f2dfa42b979eea8.jpg: 640x640 2 potholes, 7.5ms
# image 2/59 /content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images/1014748_RS_386_386RS124739_30665_RAW_jpg.rf.cafbfec901452edfbb14611ead7186ae.jpg: 640x640 (no detections), 7.4ms
# image 3/59 /content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images/1014760_RS_386_386RS124739_30725_RAW_jpg.rf.599598b829254013fd489f18f5862067.jpg: 640x640 1 pothole, 7.5ms
# image 4/59 /content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images/1014783_RS_386_386RS124739_30840_RAW_jpg.rf.3734fa1209204c0aec525d6c76e754a1.jpg: 640x640 1 pothole, 7.4ms
# image 5/59 /content/drive/MyDrive/potholesecond/test-20250225T102450Z-001/test/images/1014790_RS_386_386RS124739_30875_RAW_jpg.rf.5ec9cb2f74eb278d4294b5f877c1ac45.jpg: 640x640 2 potholes, 7.4ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:8]:
    display(IPyImage(filename=img, width=300))
    print("\n")

# %%
from google.colab import drive
drive.mount('/content/drive')  # Mount Google Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

src = "/content/runs/detect/train/weights/best.pt"  # 🔹 Source file (the trained model)
dst = "/content/drive/MyDrive/best.pt"     # 🔹 Destination path (Google Drive)

shutil.copy(src, dst)  # Copy the file
print("Model saved successfully!")
# Out:
# Model saved successfully!
