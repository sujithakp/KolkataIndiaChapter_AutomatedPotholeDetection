# %%
# !nvidia-smi
# Out:
# Sat Mar  8 09:00:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.pt")

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/potholeyolo/data.yaml",  # Path to dataset YAML
    epochs=150,  # Total training epochs
    patience=20,  # Number of epochs to wait for improvement before stopping early
    imgsz=640,  # Training image size
    device=0,  # Device to run on (0 = GPU, 'cpu' = CPU)
)
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.pt")

# Train the model
train_results = model.train(
    data="/content/drive/MyDrive/potholeyolo/data.yaml",  # path to dataset YAML
    epochs=150,
    patience=20, # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 313MB/s]
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/drive/MyDrive/potholeyolo/test/images", save=True)
results[0].show()
# Out:
# image 1/138 /content/drive/MyDrive/potholeyolo/test/images/img-101_jpg.rf.4324cfa1bd9be81c8cbb813f74420e9e.jpg: 640x640 2 potholes, 36.2ms
# image 2/138 /content/drive/MyDrive/potholeyolo/test/images/img-102_jpg.rf.5f0474f9d6d0de811c90606d7b217e95.jpg: 640x640 1 pothole, 71.1ms
# image 3/138 /content/drive/MyDrive/potholeyolo/test/images/img-133_jpg.rf.aa5e0ac6245e4fde5cb280c56d8a030a.jpg: 640x640 1 pothole, 36.3ms
# image 4/138 /content/drive/MyDrive/potholeyolo/test/images/img-136_jpg.rf.44c5d5b7e1f54208dce1e72f840edd28.jpg: 640x640 1 pothole, 37.6ms
# image 5/138 /content/drive/MyDrive/potholeyolo/test/images/img-139_jpg.rf.6a565f9a90a4da5d2ec37886adf59b01.jpg: 640x640 1 pothole, 36.1ms
# image 6/138 /content/drive/MyDrive/potholeyolo/test/images/img-145_jpg.rf.4e47741bf5d63af925efd2ae38194eb0.jpg: 640x640 1 pothole, 37.2ms
# image 7/138 /content/drive/MyDrive/potholeyolo/test/images/img-154_jpg.rf.275a44e452c66013482552bcde43c5e9.jpg: 640x640 2 potholes, 36.0ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:8]:
    display(IPyImage(filename=img, width=300))
    print("\n")

# %%
from google.colab import drive
drive.mount('/content/drive')  # Mount Google Drive
# Out:
# Mounted at /content/drive

# %%
import shutil

src = "/content/runs/detect/train/weights/best.pt"  # 🔹 Source file (the trained model)
dst = "/content/drive/MyDrive/best.pt"     # 🔹 Destination path (Google Drive)

shutil.copy(src, dst)  # Copy the file
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import pandas as pd
import json

# If saved as CSV
df = pd.read_csv("confusion_matrix.csv")
print(df)

# If saved as JSON
with open("metrics.json", "r") as f:
    metrics = json.load(f)
print(metrics)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-72b1fc2b5215> in <cell line: 0>()
#       3
#       4 # If saved as CSV
# ----> 5 df = pd.read_csv("confusion_matrix.csv")
#       6 print(df)
#       7
#
# ...

# %%
# Load entire model
model = torch.load("model.pth")
model.eval()

# Load model weights (if saved using state_dict)
model.load_state_dict(torch.load("model_weights.pth"))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fa36abd52f52> in <cell line: 0>()
#       1 # Load entire model
# ----> 2 model = torch.load("model.pth")
#       3 model.eval()
#       4
#       5 # Load model weights (if saved using state_dict)
#
# NameError: name 'torch' is not defined
